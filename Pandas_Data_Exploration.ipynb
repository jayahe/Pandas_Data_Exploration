# %% [markdown]
# # Practice Session
# # Data Exploration using Pandas
# ### HR_Employee_Attriton_Data

# %%
import os
os.getcwd()
os.listdir()

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('C:\Myfolders\Learning\Acadgild\Course Material\Pandas Session1\HR_Employee_Attrition_Data.csv')

# %%
df.shape
# Out:
# (2940, 35)

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.head(2)
# df.tail(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
#
#            ...           RelationshipSatisfaction StandardHours  \
# 0          ...                                  1            80
# 1          ...                                  4            80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                  8                      0               1
# 1                 1                 10                      3               3
#
#    YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  2940.000000  2940.000000       2940.000000  2940.000000         2940.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.133819   403.440447          8.105485     1.023991            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     2940.000000              2940.000000  2940.000000     2940.000000
# mean      1470.500000                 2.721769    65.891156        2.729932
# ...

# %%
df_cat = df.dtypes[df.dtypes == 'object'].index
df_num = df.dtypes[df.dtypes != 'object'].index
print('\nNumerical Variables\n','-'*25)
print(df_num)
print('\n Categorical Variables\n','-'*30)
print(df_cat)
# Out:
# Numerical Variables
#  -------------------------
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')
#
#  Categorical Variables
#  ------------------------------
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
# Summary of categorical variables
df[df_cat].describe()
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       2940           2940                    2940           2940   2940
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        2466           2086                    1922           1212   1764
#
#                 JobRole MaritalStatus Over18 OverTime
# count              2940          2940   2940     2940
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                652          1346   2940     2108

# %%
del df['MaritalStatus']

# %%
sorted(df['EmployeeNumber'])

# %%
df['Age'].describe()
# Out:
# count    2940.000000
# mean       36.923810
# std         9.133819
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %%
df['Over18'].describe()
# Out:
# count     2940
# unique       1
# top          Y
# freq      2940
# Name: Over18, dtype: object

# %%
df['Over18'][0:2]
# Out:
# 0    Y
# 1    Y
# Name: Over18, dtype: object

# %%
# Change the levels within a column
New_Over18 = pd.Categorical(df['Over18'])
New_Over18 = New_Over18.rename_categories(['Yes'])
New_Over18.describe()
# Out:
#             counts  freqs
# categories
# Yes           2940    1.0

# %%
New_BusinessTravel = pd.Categorical(df['BusinessTravel'],ordered = True)
New_BusinessTravel = New_BusinessTravel.rename_categories(['NonTravel','TravelFrequently','TraveRarely'])
New_BusinessTravel.describe()
# Out:
#                   counts     freqs
# categories
# NonTravel            300  0.102041
# TravelFrequently     554  0.188435
# TraveRarely         2086  0.709524

# %%
# Rename a column
df['BusinessTravel'] = New_BusinessTravel
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
print(df['Age'].unique())
print('\n','-'*30)
print(New_BusinessTravel.unique())
# Out:
# [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43 50
#  26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
#
#  ------------------------------
# [TraveRarely, TravelFrequently, NonTravel]
# Categories (3, object): [NonTravel < TravelFrequently < TraveRarely]

# %%
df['EducationField'].describe()
# Out:
# count              2940
# unique                6
# top       Life Sciences
# freq               1212
# Name: EducationField, dtype: object

# %%
char_EducationField = df['EducationField'].astype(str)
New_EducationField = np.array(EducationField for i in char_EducationField)
# New_EducationField = pd.Categorical(New_EducationField)
print(New_EducationField)
# Out:
# <generator object <genexpr> at 0x0A33E030>

# %%
# Finding NULL Values
dummy_vector = pd.Series([1,None,3,None,7,9])
dummy_vector.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
# Finding Missing Values
index = np.where(df.isnull() == True)
print(len(missing[0]))
df.loc[index]
# Out:
# 0
# Empty DataFrame
# Columns: []
# Index: []

# %%
index1 = np.where((df['Age'] == max(df['Age'])) &(df['Department']=='Sales'))
df.loc[index1]
# Out:
#       Age Attrition    BusinessTravel  DailyRate Department  DistanceFromHome  \
# 427    60        No  TravelFrequently       1499      Sales                28
# 536    60        No       TraveRarely       1179      Sales                16
# 879    60        No       TraveRarely        696      Sales                 7
# 1897   60        No  TravelFrequently       1499      Sales                28
# 2006   60        No       TraveRarely       1179      Sales                16
# 2349   60        No       TraveRarely        696      Sales                 7
#
#       Education EducationField  EmployeeCount  EmployeeNumber  \
# 427           3      Marketing              1             428
# 536           4      Marketing              1             537
# 879           4      Marketing              1             880
# 1897          3      Marketing              1            1898
# 2006          4      Marketing              1            2007
# ...

# %%
# Creating a derived field
df['YearsAtOtherRole'] = df['YearsAtCompany'] - df['YearsInCurrentRole']
max_otherrole = np.where(df['YearsAtOtherRole'] == max(df['YearsAtOtherRole']))
df.loc[max_otherrole]
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 126    58       Yes    TraveRarely        147  Research & Development
# 1116   55        No    TraveRarely        685                   Sales
# 1596   58       Yes    TraveRarely        147  Research & Development
# 2586   55        No    TraveRarely        685                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 126                 23          4        Medical              1
# 1116                26          5      Marketing              1
# 1596                23          4        Medical              1
# 2586                26          5      Marketing              1
#
#       EmployeeNumber        ...         StandardHours StockOptionLevel  \
# 126              127        ...                    80                1
# 1116            1117        ...                    80                1
# 1596            1597        ...                    80                1
# ...

# %%
# No.of Attrition
index2 = np.where(df['Attrition']=='Yes')
print('\n No of Attritions\n','-'*30)
print(len(df.loc[index2]))
index3 = np.where(df['Attrition']=='No')
len(df.loc[index3])
print('\nNo of Non Attrition\n','-'*30)
print(len(df.loc[index3]))
# Out:
#  No of Attritions
#  ------------------------------
# 474
#
# No of Non Attrition
#  ------------------------------
# 2466

# %%
df.shape
# Out:
# (2940, 35)
